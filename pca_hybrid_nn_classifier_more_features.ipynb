# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout

# !pip install fastparquet
# !pip install shap
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2023.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.23.5)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.7.0 fastparquet-2023.8.0
# Collecting shap
#   Downloading shap-0.42.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.42.1 slicer-0.0.7

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Tue Sep  5 21:25:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    44W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# Read the processed dataset.
# semg_df = pd.read_parquet('/content/drive/MyDrive/sEMG-HAR/semg_extracted_features_only', engine='fastparquet')
semg_df = pd.read_parquet('/content/drive/MyDrive/sEMG-HAR/semg_extracted_more_features', engine='fastparquet')

semg_df
# Out:
#       subject_id  activity  trial_index  semg_1_td_mean  semg_1_td_rms  \
# 0              5        20            3        0.007527      32.994613
# 1             10        20            4       -0.006587      44.476383
# 2              6        20           10        0.001336       8.073858
# 3              1        20            9        0.002790      21.087234
# 4              8        20           10        0.000866      41.998197
# ...          ...       ...          ...             ...            ...
# 1171           6        11            6        0.000350       9.513134
# 1172           5        11            9        0.001527      16.755570
# 1173          10        11            3        0.014783      19.585490
# 1174           7        11            1        0.004954      20.974539
# 1175           1        11            4       -0.000558      24.513412
#
#       semg_1_td_sd  semg_1_td_var  semg_1_td_iemg  semg_1_td_zcr  \
# 0        32.994613    1088.644456   465531.475412           2317
# 1        44.476383    1978.148624   429311.110991           2114
# 2         8.073858      65.187177   124953.964457           3182
# 3        21.087233     444.671412   324534.585663           2833
# 4        41.998197    1763.848562   481195.451785           3024
# ...            ...            ...             ...            ...
# 1171      9.513134      90.499723   130480.665329           2364
# 1172     16.755570     280.749127   174589.108879           2231
# 1173     19.585484     383.591200   263334.699756           1942
# 1174     20.974538     439.931262   273930.161664           1881
# 1175     24.513412     600.907346   337177.979915           2220
#
#       semg_1_td_ssc  ...                                  semg_3_tfd_hjorth  \
# 0              4180  ...  [7.708834652764494, 7.709010892616439, 7.70954...
# 1              4012  ...  [153.78781638860954, 153.78786196755996, 153.7...
# 2              5333  ...  [322.1779260799889, 322.1789827395294, 322.182...
# 3              4778  ...  [1.348005314617751, 1.3480321269880162, 1.3481...
# 4              5038  ...  [23.12080078554669, 23.121273762321056, 23.122...
# ...             ...  ...                                                ...
# 1171           4103  ...  [24.869527038763188, 24.86968772605987, 24.870...
# 1172           4015  ...  [22.595723483197432, 22.599108095770582, 22.60...
# 1173           3812  ...  [53.377419007268166, 53.3783863579666, 53.3812...
# 1174           3339  ...  [1.8965386191367202, 1.902438707844022, 1.9200...
# 1175           3918  ...  [9.445164956738054, 9.445237745730886, 9.44545...
#
#                                     semg_3_tfd_arcoeffs  \
# 0     [7.708834652764494, 7.709010892616439, 7.70954...
# 1     [153.78781638860954, 153.78786196755996, 153.7...
# 2     [322.1779260799889, 322.1789827395294, 322.182...
# 3     [1.348005314617751, 1.3480321269880162, 1.3481...
# 4     [23.12080078554669, 23.121273762321056, 23.122...
# ...                                                 ...
# 1171  [24.869527038763188, 24.86968772605987, 24.870...
# 1172  [22.595723483197432, 22.599108095770582, 22.60...
# 1173  [53.377419007268166, 53.3783863579666, 53.3812...
# 1174  [1.8965386191367202, 1.902438707844022, 1.9200...
# 1175  [9.445164956738054, 9.445237745730886, 9.44545...
#
#                                         semg_4_tfd_stft  \
# 0     [1.0064211140819452, 1.0092077942869477, 1.017...
# 1     [613.5029555407747, 613.5050181882475, 613.511...
# 2     [468.2028466841613, 468.2122601584829, 468.240...
# 3     [52.352982899279134, 52.35321899582158, 52.353...
# 4     [30.107865417110588, 30.107955036601975, 30.10...
# ...                                                 ...
# 1171  [3.5199747069944465, 3.5198081203170544, 3.519...
# 1172  [8.658719952547358, 8.659247997878357, 8.66084...
# 1173  [324.7154344506416, 324.71656154910306, 324.71...
# 1174  [21.33213555003323, 21.33423471702555, 21.3405...
# 1175  [419.3928938755001, 419.3973041180371, 419.410...
#
#                                         semg_4_tfd_mfcc  \
# 0     [1.0064211140819452, 1.0092077942869477, 1.017...
# 1     [613.5029555407747, 613.5050181882475, 613.511...
# 2     [468.2028466841613, 468.2122601584829, 468.240...
# 3     [52.352982899279134, 52.35321899582158, 52.353...
# 4     [30.107865417110588, 30.107955036601975, 30.10...
# ...                                                 ...
# 1171  [3.5199747069944465, 3.5198081203170544, 3.519...
# 1172  [8.658719952547358, 8.659247997878357, 8.66084...
# 1173  [324.7154344506416, 324.71656154910306, 324.71...
# 1174  [21.33213555003323, 21.33423471702555, 21.3405...
# 1175  [419.3928938755001, 419.3973041180371, 419.410...
#
#                                       semg_4_tfd_hjorth  \
# 0     [1.0064211140819452, 1.0092077942869477, 1.017...
# 1     [613.5029555407747, 613.5050181882475, 613.511...
# 2     [468.2028466841613, 468.2122601584829, 468.240...
# 3     [52.352982899279134, 52.35321899582158, 52.353...
# 4     [30.107865417110588, 30.107955036601975, 30.10...
# ...                                                 ...
# 1171  [3.5199747069944465, 3.5198081203170544, 3.519...
# 1172  [8.658719952547358, 8.659247997878357, 8.66084...
# 1173  [324.7154344506416, 324.71656154910306, 324.71...
# 1174  [21.33213555003323, 21.33423471702555, 21.3405...
# 1175  [419.3928938755001, 419.3973041180371, 419.410...
#
#                                     semg_4_tfd_arcoeffs  \
# 0     [1.0064211140819452, 1.0092077942869477, 1.017...
# 1     [613.5029555407747, 613.5050181882475, 613.511...
# 2     [468.2028466841613, 468.2122601584829, 468.240...
# 3     [52.352982899279134, 52.35321899582158, 52.353...
# 4     [30.107865417110588, 30.107955036601975, 30.10...
# ...                                                 ...
# 1171  [3.5199747069944465, 3.5198081203170544, 3.519...
# 1172  [8.658719952547358, 8.659247997878357, 8.66084...
# 1173  [324.7154344506416, 324.71656154910306, 324.71...
# 1174  [21.33213555003323, 21.33423471702555, 21.3405...
# 1175  [419.3928938755001, 419.3973041180371, 419.410...
#
#                                         semg_5_tfd_stft  \
# 0     [310.56733342211373, 310.5691632707391, 310.57...
# 1     [45.36440806490623, 45.36743359968911, 45.3765...
# 2     [2.1613993955644375, 2.161413970956996, 2.1614...
# 3     [6.648577666104643, 6.64867443223733, 6.648965...
# 4     [0.9820094907973669, 0.9820031528972324, 0.981...
# ...                                                 ...
# 1171  [2.8651581711222676, 2.8651377616485254, 2.865...
# 1172  [3465.4448361652876, 3465.502393564784, 3465.6...
# 1173  [576.3102442592726, 576.3208419638165, 576.352...
# 1174  [1975.3057176576308, 1975.3051327365372, 1975....
# 1175  [713.6383088758662, 713.6524524836674, 713.694...
#
#                                         semg_5_tfd_mfcc  \
# 0     [310.56733342211373, 310.5691632707391, 310.57...
# 1     [45.36440806490623, 45.36743359968911, 45.3765...
# 2     [2.1613993955644375, 2.161413970956996, 2.1614...
# 3     [6.648577666104643, 6.64867443223733, 6.648965...
# 4     [0.9820094907973669, 0.9820031528972324, 0.981...
# ...                                                 ...
# 1171  [2.8651581711222676, 2.8651377616485254, 2.865...
# 1172  [3465.4448361652876, 3465.502393564784, 3465.6...
# 1173  [576.3102442592726, 576.3208419638165, 576.352...
# 1174  [1975.3057176576308, 1975.3051327365372, 1975....
# 1175  [713.6383088758662, 713.6524524836674, 713.694...
#
#                                       semg_5_tfd_hjorth  \
# 0     [310.56733342211373, 310.5691632707391, 310.57...
# 1     [45.36440806490623, 45.36743359968911, 45.3765...
# 2     [2.1613993955644375, 2.161413970956996, 2.1614...
# 3     [6.648577666104643, 6.64867443223733, 6.648965...
# 4     [0.9820094907973669, 0.9820031528972324, 0.981...
# ...                                                 ...
# 1171  [2.8651581711222676, 2.8651377616485254, 2.865...
# 1172  [3465.4448361652876, 3465.502393564784, 3465.6...
# 1173  [576.3102442592726, 576.3208419638165, 576.352...
# 1174  [1975.3057176576308, 1975.3051327365372, 1975....
# 1175  [713.6383088758662, 713.6524524836674, 713.694...
#
#                                     semg_5_tfd_arcoeffs
# 0     [310.56733342211373, 310.5691632707391, 310.57...
# 1     [45.36440806490623, 45.36743359968911, 45.3765...
# 2     [2.1613993955644375, 2.161413970956996, 2.1614...
# 3     [6.648577666104643, 6.64867443223733, 6.648965...
# 4     [0.9820094907973669, 0.9820031528972324, 0.981...
# ...                                                 ...
# 1171  [2.8651581711222676, 2.8651377616485254, 2.865...
# 1172  [3465.4448361652876, 3465.502393564784, 3465.6...
# 1173  [576.3102442592726, 576.3208419638165, 576.352...
# 1174  [1975.3057176576308, 1975.3051327365372, 1975....
# 1175  [713.6383088758662, 713.6524524836674, 713.694...
#
# [1176 rows x 483 columns]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, concatenate
from tensorflow.keras.preprocessing.sequence import pad_sequences

NO_WINDOWS = 10

# Select sequential type features and 'activity' column
non_scalar_features = ['activity', 'semg_1_fd_fft', 'semg_2_fd_fft', 'semg_3_fd_fft', 'semg_4_fd_fft', 'semg_5_fd_fft',
                      'semg_1_fd_psd', 'semg_2_fd_psd', 'semg_3_fd_psd', 'semg_4_fd_psd', 'semg_5_fd_psd',
                      'semg_1_tfd_stft', 'semg_2_tfd_stft', 'semg_3_tfd_stft', 'semg_4_tfd_stft', 'semg_5_tfd_stft',
                      'semg_1_tfd_mfcc', 'semg_2_tfd_mfcc', 'semg_3_tfd_mfcc', 'semg_4_tfd_mfcc', 'semg_5_tfd_mfcc',
                      'semg_1_tfd_hjorth', 'semg_2_tfd_hjorth', 'semg_3_tfd_hjorth', 'semg_4_tfd_hjorth', 'semg_5_tfd_hjorth',
                      'semg_1_tfd_arcoeffs', 'semg_2_tfd_arcoeffs', 'semg_3_tfd_arcoeffs', 'semg_4_tfd_arcoeffs', 'semg_5_tfd_arcoeffs']

# Select only scalar type features by dropping sequential type features and the 'activity' column
scalar_X = semg_df.drop(columns=non_scalar_features)

# Select sequential type features only
non_scalar_features = ['semg_1_fd_fft', 'semg_2_fd_fft', 'semg_3_fd_fft', 'semg_4_fd_fft', 'semg_5_fd_fft',
                      'semg_1_fd_psd', 'semg_2_fd_psd', 'semg_3_fd_psd', 'semg_4_fd_psd', 'semg_5_fd_psd',
                      'semg_1_tfd_stft', 'semg_2_tfd_stft', 'semg_3_tfd_stft', 'semg_4_tfd_stft', 'semg_5_tfd_stft',
                      'semg_1_tfd_mfcc', 'semg_2_tfd_mfcc', 'semg_3_tfd_mfcc', 'semg_4_tfd_mfcc', 'semg_5_tfd_mfcc',
                      'semg_1_tfd_hjorth', 'semg_2_tfd_hjorth', 'semg_3_tfd_hjorth', 'semg_4_tfd_hjorth', 'semg_5_tfd_hjorth',
                      'semg_1_tfd_arcoeffs', 'semg_2_tfd_arcoeffs', 'semg_3_tfd_arcoeffs', 'semg_4_tfd_arcoeffs', 'semg_5_tfd_arcoeffs']

non_scalar_X = semg_df[non_scalar_features]
y = semg_df['activity'].astype('int')

# One-hot encoding for the labels
y = to_categorical(y-1, num_classes=21)

# Extract the 'activity' column from the one-hot encoded labels
activity_labels = np.argmax(y, axis=1)

# Split data into training and validation sets while preserving class proportions using stratify
scalar_X_train, scalar_X_val, non_scalar_X_train, non_scalar_X_val, y_train, y_val = train_test_split(
    scalar_X, non_scalar_X, y, test_size=0.2, random_state=42, stratify=activity_labels
)

# Standardize the scalar data
scaler = StandardScaler()
scalar_X_train_standardized = scaler.fit_transform(scalar_X_train)
scalar_X_val_standardized = scaler.transform(scalar_X_val)

non_scalar_train_X_list = non_scalar_X_train.values
non_scalar_val_X_list = non_scalar_X_val.values

# Apply the scaler to the sequential-type columns
for col in non_scalar_X_train.columns:
    non_scalar_X_train.loc[:, col] = non_scalar_X_train[col].apply(lambda x: scaler.fit_transform(np.array(x).reshape(-1, 1)).flatten().tolist())

# Apply the scaler to the sequential-type columns
for col in non_scalar_X_val.columns:
    non_scalar_X_val.loc[:, col] = non_scalar_X_val[col].apply(lambda x: scaler.fit_transform(np.array(x).reshape(-1, 1)).flatten().tolist())

# %%
max_sequence_length = max(len(col) for sequence in non_scalar_train_X_list for col in sequence)
print("max_sequence_length: ", max_sequence_length)

# Pad the sequence data to the maximum length
X_sequence_train_padded = []
for sequence in non_scalar_train_X_list:
    sequence_padded = pad_sequences(sequence, maxlen=max_sequence_length, padding='post', truncating='post')
    X_sequence_train_padded.append(sequence_padded)
X_sequence_train_padded = np.array(X_sequence_train_padded)

X_sequence_val_padded = []
for sequence in non_scalar_val_X_list:
    sequence_padded = pad_sequences(sequence, maxlen=max_sequence_length, padding='post', truncating='post')
    X_sequence_val_padded.append(sequence_padded)
X_sequence_val_padded = np.array(X_sequence_val_padded)
# Out:
# max_sequence_length:  20000

# %% [markdown]
# Initial Basic Hybrid Model

# %%
from keras.regularizers import l1_l2

# Define the number of classes
num_classes = y_train.shape[1]

# Regularization hyperparameters
l1_lambda = 0.001  # L1 regularization hyperparameter
l2_lambda = 0.001  # L2 regularization hyperparameter


# Create FNN for scalar features
input_scalar = Input(shape=(scalar_X_train_standardized.shape[1],))
dense_layer_1 = Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(input_scalar)
dense_layer_2 = Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(dense_layer_1)

# Transpose the sequence data to match the expected shape
X_sequence_train_padded_transposed = np.transpose(X_sequence_train_padded, (0, 2, 1))
X_sequence_val_padded_transposed = np.transpose(X_sequence_val_padded, (0, 2, 1))

# Create RNN for sequence data
input_sequence = Input(shape=(max_sequence_length, non_scalar_X_train.shape[1]))
rnn_layer = LSTM(128)(input_sequence)

# After dense_layer_2 and rnn_layer
dense_layer_dropout = Dropout(0.5)(dense_layer_2)
rnn_layer_dropout = Dropout(0.5)(rnn_layer)

# Merge the outputs of FNN and RNN with dropout
merged_output = concatenate([dense_layer_dropout, rnn_layer_dropout])

# Add classification layer
output_layer = Dense(num_classes, activation='softmax')(merged_output)

# Create the model
model = Model(inputs=[input_scalar, input_sequence], outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 100
batch_size = 128

# Train the model
history = model.fit([scalar_X_train_standardized, X_sequence_train_padded_transposed], y_train,
          validation_data=([scalar_X_val_standardized, X_sequence_val_padded_transposed], y_val),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 15s 805ms/step - loss: 5.0275 - accuracy: 0.0681 - val_loss: 4.9257 - val_accuracy: 0.1398
# Epoch 2/100
# 8/8 [==============================] - 5s 689ms/step - loss: 4.7146 - accuracy: 0.1447 - val_loss: 4.6910 - val_accuracy: 0.2669
# Epoch 3/100
# 8/8 [==============================] - 5s 687ms/step - loss: 4.5290 - accuracy: 0.1979 - val_loss: 4.4667 - val_accuracy: 0.3220
# Epoch 4/100
# 8/8 [==============================] - 5s 688ms/step - loss: 4.3552 - accuracy: 0.2245 - val_loss: 4.2597 - val_accuracy: 0.4110
# Epoch 5/100
# 8/8 [==============================] - 5s 687ms/step - loss: 4.1411 - accuracy: 0.2851 - val_loss: 4.0554 - val_accuracy: 0.4661
# Epoch 6/100
# 8/8 [==============================] - 5s 688ms/step - loss: 3.9633 - accuracy: 0.3213 - val_loss: 3.8778 - val_accuracy: 0.4576
# Epoch 7/100
# 8/8 [==============================] - 5s 694ms/step - loss: 3.7715 - accuracy: 0.3564 - val_loss: 3.6882 - val_accuracy: 0.5000
# Epoch 8/100
# 8/8 [==============================] - 5s 693ms/step - loss: 3.6240 - accuracy: 0.3872 - val_loss: 3.5220 - val_accuracy: 0.5254
# Epoch 9/100
# 8/8 [==============================] - 5s 695ms/step - loss: 3.4412 - accuracy: 0.4543 - val_loss: 3.3808 - val_accuracy: 0.5720
# Epoch 10/100
# 8/8 [==============================] - 6s 697ms/step - loss: 3.3269 - accuracy: 0.4585 - val_loss: 3.2433 - val_accuracy: 0.5424
# Epoch 11/100
# 8/8 [==============================] - 5s 693ms/step - loss: 3.1743 - accuracy: 0.4830 - val_loss: 3.1194 - val_accuracy: 0.5932
# Epoch 12/100
# 8/8 [==============================] - 5s 687ms/step - loss: 3.0723 - accuracy: 0.4926 - val_loss: 2.9985 - val_accuracy: 0.6186
# Epoch 13/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.9428 - accuracy: 0.5362 - val_loss: 2.9041 - val_accuracy: 0.6229
# Epoch 14/100
# 8/8 [==============================] - 5s 688ms/step - loss: 2.8533 - accuracy: 0.5415 - val_loss: 2.8044 - val_accuracy: 0.6314
# Epoch 15/100
# 8/8 [==============================] - 5s 692ms/step - loss: 2.7439 - accuracy: 0.5713 - val_loss: 2.7068 - val_accuracy: 0.6525
# Epoch 16/100
# 8/8 [==============================] - 5s 690ms/step - loss: 2.6788 - accuracy: 0.5660 - val_loss: 2.6373 - val_accuracy: 0.6695
# Epoch 17/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.6342 - accuracy: 0.5638 - val_loss: 2.5492 - val_accuracy: 0.6822
# Epoch 18/100
# 8/8 [==============================] - 5s 690ms/step - loss: 2.5576 - accuracy: 0.5713 - val_loss: 2.4883 - val_accuracy: 0.6568
# Epoch 19/100
# 8/8 [==============================] - 5s 693ms/step - loss: 2.5180 - accuracy: 0.5819 - val_loss: 2.4469 - val_accuracy: 0.6907
# Epoch 20/100
# 8/8 [==============================] - 5s 692ms/step - loss: 2.4145 - accuracy: 0.6181 - val_loss: 2.3748 - val_accuracy: 0.6653
# Epoch 21/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.3655 - accuracy: 0.6106 - val_loss: 2.3088 - val_accuracy: 0.6907
# Epoch 22/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.2947 - accuracy: 0.6074 - val_loss: 2.2539 - val_accuracy: 0.7034
# Epoch 23/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.2563 - accuracy: 0.6309 - val_loss: 2.2098 - val_accuracy: 0.7161
# Epoch 24/100
# 8/8 [==============================] - 5s 690ms/step - loss: 2.1825 - accuracy: 0.6468 - val_loss: 2.1607 - val_accuracy: 0.7076
# Epoch 25/100
# 8/8 [==============================] - 5s 689ms/step - loss: 2.1667 - accuracy: 0.6298 - val_loss: 2.1176 - val_accuracy: 0.7034
# Epoch 26/100
# 8/8 [==============================] - 5s 692ms/step - loss: 2.0851 - accuracy: 0.6734 - val_loss: 2.0706 - val_accuracy: 0.7161
# Epoch 27/100
# 8/8 [==============================] - 5s 689ms/step - loss: 2.0496 - accuracy: 0.6702 - val_loss: 2.0331 - val_accuracy: 0.7373
# Epoch 28/100
# 8/8 [==============================] - 5s 688ms/step - loss: 1.9894 - accuracy: 0.6766 - val_loss: 1.9949 - val_accuracy: 0.7034
# Epoch 29/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.9863 - accuracy: 0.6681 - val_loss: 1.9619 - val_accuracy: 0.7034
# Epoch 30/100
# 8/8 [==============================] - 5s 696ms/step - loss: 1.9615 - accuracy: 0.6830 - val_loss: 1.9314 - val_accuracy: 0.7119
# Epoch 31/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.9192 - accuracy: 0.6787 - val_loss: 1.8903 - val_accuracy: 0.7288
# Epoch 32/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.8722 - accuracy: 0.6904 - val_loss: 1.8653 - val_accuracy: 0.7415
# Epoch 33/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.8459 - accuracy: 0.7128 - val_loss: 1.8217 - val_accuracy: 0.7288
# Epoch 34/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.8274 - accuracy: 0.6830 - val_loss: 1.7990 - val_accuracy: 0.7161
# Epoch 35/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.7826 - accuracy: 0.7138 - val_loss: 1.7673 - val_accuracy: 0.7627
# Epoch 36/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.7412 - accuracy: 0.7074 - val_loss: 1.7377 - val_accuracy: 0.7542
# Epoch 37/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.7253 - accuracy: 0.7128 - val_loss: 1.7126 - val_accuracy: 0.7373
# Epoch 38/100
# 8/8 [==============================] - 5s 697ms/step - loss: 1.7031 - accuracy: 0.7117 - val_loss: 1.6988 - val_accuracy: 0.7373
# Epoch 39/100
# 8/8 [==============================] - 5s 696ms/step - loss: 1.7213 - accuracy: 0.7043 - val_loss: 1.6748 - val_accuracy: 0.7627
# Epoch 40/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.6578 - accuracy: 0.7362 - val_loss: 1.6695 - val_accuracy: 0.7500
# Epoch 41/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.6265 - accuracy: 0.7266 - val_loss: 1.6428 - val_accuracy: 0.7542
# Epoch 42/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.6423 - accuracy: 0.7181 - val_loss: 1.6099 - val_accuracy: 0.7458
# Epoch 43/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.5932 - accuracy: 0.7372 - val_loss: 1.6114 - val_accuracy: 0.7500
# Epoch 44/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.5529 - accuracy: 0.7553 - val_loss: 1.5961 - val_accuracy: 0.7542
# Epoch 45/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.5847 - accuracy: 0.7202 - val_loss: 1.5920 - val_accuracy: 0.7373
# Epoch 46/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.5348 - accuracy: 0.7500 - val_loss: 1.5753 - val_accuracy: 0.7627
# Epoch 47/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.5283 - accuracy: 0.7394 - val_loss: 1.5449 - val_accuracy: 0.7585
# Epoch 48/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.5023 - accuracy: 0.7372 - val_loss: 1.5253 - val_accuracy: 0.7712
# Epoch 49/100
# 8/8 [==============================] - 5s 696ms/step - loss: 1.4987 - accuracy: 0.7596 - val_loss: 1.5026 - val_accuracy: 0.7669
# Epoch 50/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.4934 - accuracy: 0.7606 - val_loss: 1.4914 - val_accuracy: 0.7754
# Epoch 51/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.4643 - accuracy: 0.7755 - val_loss: 1.5003 - val_accuracy: 0.7712
# Epoch 52/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.4559 - accuracy: 0.7617 - val_loss: 1.5040 - val_accuracy: 0.7712
# Epoch 53/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.4480 - accuracy: 0.7489 - val_loss: 1.4908 - val_accuracy: 0.7669
# Epoch 54/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.4235 - accuracy: 0.7702 - val_loss: 1.4919 - val_accuracy: 0.7712
# Epoch 55/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.4243 - accuracy: 0.7681 - val_loss: 1.5069 - val_accuracy: 0.7712
# Epoch 56/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.4004 - accuracy: 0.7809 - val_loss: 1.4988 - val_accuracy: 0.7712
# Epoch 57/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.3954 - accuracy: 0.7840 - val_loss: 1.4517 - val_accuracy: 0.7797
# Epoch 58/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.3821 - accuracy: 0.7915 - val_loss: 1.4411 - val_accuracy: 0.7712
# Epoch 59/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.3589 - accuracy: 0.7968 - val_loss: 1.4300 - val_accuracy: 0.7797
# Epoch 60/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.3620 - accuracy: 0.7723 - val_loss: 1.4257 - val_accuracy: 0.7924
# Epoch 61/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.3708 - accuracy: 0.7745 - val_loss: 1.3759 - val_accuracy: 0.7839
# Epoch 62/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.3247 - accuracy: 0.7798 - val_loss: 1.3430 - val_accuracy: 0.7839
# Epoch 63/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.3380 - accuracy: 0.7872 - val_loss: 1.3571 - val_accuracy: 0.7797
# Epoch 64/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.3382 - accuracy: 0.7787 - val_loss: 1.3733 - val_accuracy: 0.7881
# Epoch 65/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.3141 - accuracy: 0.7926 - val_loss: 1.3379 - val_accuracy: 0.7754
# Epoch 66/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.3062 - accuracy: 0.7979 - val_loss: 1.3333 - val_accuracy: 0.7754
# Epoch 67/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.3095 - accuracy: 0.7809 - val_loss: 1.3477 - val_accuracy: 0.7881
# Epoch 68/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2800 - accuracy: 0.8096 - val_loss: 1.3481 - val_accuracy: 0.7881
# Epoch 69/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2898 - accuracy: 0.8000 - val_loss: 1.3580 - val_accuracy: 0.7881
# Epoch 70/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.3070 - accuracy: 0.7851 - val_loss: 1.3348 - val_accuracy: 0.7881
# Epoch 71/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.2853 - accuracy: 0.7872 - val_loss: 1.3386 - val_accuracy: 0.7881
# Epoch 72/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.2876 - accuracy: 0.7979 - val_loss: 1.3386 - val_accuracy: 0.8008
# Epoch 73/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.2428 - accuracy: 0.8117 - val_loss: 1.2966 - val_accuracy: 0.7881
# Epoch 74/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.2808 - accuracy: 0.8000 - val_loss: 1.2896 - val_accuracy: 0.8136
# Epoch 75/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.2648 - accuracy: 0.8138 - val_loss: 1.3214 - val_accuracy: 0.8051
# Epoch 76/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2238 - accuracy: 0.8181 - val_loss: 1.3072 - val_accuracy: 0.7924
# Epoch 77/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.2160 - accuracy: 0.8096 - val_loss: 1.3212 - val_accuracy: 0.7924
# Epoch 78/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.2308 - accuracy: 0.7957 - val_loss: 1.3540 - val_accuracy: 0.7966
# Epoch 79/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.2372 - accuracy: 0.8117 - val_loss: 1.3556 - val_accuracy: 0.8093
# Epoch 80/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.2305 - accuracy: 0.8032 - val_loss: 1.2982 - val_accuracy: 0.7966
# Epoch 81/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.2113 - accuracy: 0.8074 - val_loss: 1.2588 - val_accuracy: 0.8093
# Epoch 82/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2347 - accuracy: 0.7862 - val_loss: 1.3069 - val_accuracy: 0.7839
# Epoch 83/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2088 - accuracy: 0.8234 - val_loss: 1.2783 - val_accuracy: 0.7924
# Epoch 84/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.2055 - accuracy: 0.7979 - val_loss: 1.2702 - val_accuracy: 0.8008
# Epoch 85/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2013 - accuracy: 0.8021 - val_loss: 1.2840 - val_accuracy: 0.8093
# Epoch 86/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.2190 - accuracy: 0.8096 - val_loss: 1.2954 - val_accuracy: 0.8178
# Epoch 87/100
# 8/8 [==============================] - 6s 699ms/step - loss: 1.1773 - accuracy: 0.8255 - val_loss: 1.3022 - val_accuracy: 0.7924
# Epoch 88/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.1501 - accuracy: 0.8394 - val_loss: 1.2894 - val_accuracy: 0.8051
# Epoch 89/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.1817 - accuracy: 0.8138 - val_loss: 1.2847 - val_accuracy: 0.8008
# Epoch 90/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1184 - accuracy: 0.8511 - val_loss: 1.2738 - val_accuracy: 0.8051
# Epoch 91/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.1533 - accuracy: 0.8255 - val_loss: 1.2675 - val_accuracy: 0.7966
# Epoch 92/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.1641 - accuracy: 0.8011 - val_loss: 1.2460 - val_accuracy: 0.8008
# Epoch 93/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.1463 - accuracy: 0.8170 - val_loss: 1.2483 - val_accuracy: 0.7966
# Epoch 94/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1421 - accuracy: 0.8234 - val_loss: 1.2446 - val_accuracy: 0.8051
# Epoch 95/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.1703 - accuracy: 0.8149 - val_loss: 1.2637 - val_accuracy: 0.8051
# Epoch 96/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.1076 - accuracy: 0.8447 - val_loss: 1.2585 - val_accuracy: 0.7924
# Epoch 97/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.1415 - accuracy: 0.8266 - val_loss: 1.2484 - val_accuracy: 0.8051
# Epoch 98/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1251 - accuracy: 0.8457 - val_loss: 1.2383 - val_accuracy: 0.7797
# Epoch 99/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.1007 - accuracy: 0.8340 - val_loss: 1.2213 - val_accuracy: 0.8136
# Epoch 100/100
# 8/8 [==============================] - 5s 688ms/step - loss: 1.1096 - accuracy: 0.8351 - val_loss: 1.2158 - val_accuracy: 0.7966

# %%
from keras.utils import plot_model
# !pip install networkx
from IPython.display import Image, display

# Generate the plot
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# Display the image in the notebook
display(Image(filename='model.png'))


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Evaluate the model on the validation set
y_val_pred = model.predict([scalar_X_val_standardized, X_sequence_val_padded_transposed])
y_val_pred_classes = np.argmax(y_val_pred, axis=1)  # Convert probabilities to class labels

y_val_true_classes = np.argmax(y_val, axis=1)  # Convert one-hot encoded labels to class labels

# Calculate metrics
accuracy = accuracy_score(y_val_true_classes, y_val_pred_classes)
precision = precision_score(y_val_true_classes, y_val_pred_classes, average='weighted')
recall = recall_score(y_val_true_classes, y_val_pred_classes, average='weighted')
f1 = f1_score(y_val_true_classes, y_val_pred_classes, average='weighted')

print("Validation Set Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")



fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color=color)
line1, = ax1.plot(history.history['loss'], color=color, label='Train Loss')
line2, = ax1.plot(history.history['val_loss'], color=color, linestyle='dashed', label='Val Loss')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Accuracy', color=color)
line3, = ax2.plot(history.history['accuracy'], color=color, label='Train Acc')
line4, = ax2.plot(history.history['val_accuracy'], color=color, linestyle='dashed', label='Val Acc')
ax2.tick_params(axis='y', labelcolor=color)

# Added this line
lns = [line1, line2, line3, line4]
ax1.legend(handles=lns, loc='center right')

fig.tight_layout()
plt.show()

# Make predictions using the trained model
y_pred = model.predict([scalar_X_val_standardized, X_sequence_val_padded_transposed])

# Convert the one-hot encoded predictions back to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_val, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)

# Plot the confusion matrix
classes = ['activity' + str(x+1) for x in range(0, 21)]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='viridis', values_format='d')

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(rotation=90)
plt.show()

print("y_val", y_val.shape)
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# 8/8 [==============================] - 2s 222ms/step
# Validation Set Metrics:
# Accuracy: 0.7966
# Precision: 0.8109
# Recall: 0.7966
# F1-Score: 0.7988
# 8/8 [==============================] - 2s 221ms/step
# y_val (236, 21)

# %% [markdown]
# Applying PCA to the Scalar features.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Apply PCA
pca = PCA(n_components=0.99)  # Preserve 99% of the total variance
scalar_X_train_pca = pca.fit_transform(scalar_X_train_standardized)
scalar_X_val_pca = pca.transform(scalar_X_val_standardized)

# Plot the scree plot
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

plt.figure(figsize=(8, 6))
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, align='center', label='Explained Variance Ratio')
plt.plot(range(1, len(explained_variance_ratio) + 1), cumulative_variance_ratio, marker='o', color='orange', label='Cumulative Explained Variance Ratio')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.legend()
plt.show()

# %%
from keras.regularizers import l1_l2

# Define the number of classes
num_classes = y_train.shape[1]

# Regularization hyperparameters
l1_lambda = 0.001  # L1 regularization hyperparameter
l2_lambda = 0.001  # L2 regularization hyperparameter

# Create FNN for scalar features
input_scalar = Input(shape=(scalar_X_train_pca.shape[1],))
dense_layer_1 = Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(input_scalar)
dense_layer_2 = Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(dense_layer_1)

# Transpose the sequence data to match the expected shape
X_sequence_train_padded_transposed = np.transpose(X_sequence_train_padded, (0, 2, 1))
X_sequence_val_padded_transposed = np.transpose(X_sequence_val_padded, (0, 2, 1))

# Create RNN for sequence data
input_sequence = Input(shape=(max_sequence_length, non_scalar_X_train.shape[1]))
rnn_layer = LSTM(128)(input_sequence)

# After dense_layer_2 and rnn_layer
dense_layer_dropout = Dropout(0.5)(dense_layer_2)
rnn_layer_dropout = Dropout(0.5)(rnn_layer)

# Merge the outputs of FNN and RNN with dropout
merged_output = concatenate([dense_layer_dropout, rnn_layer_dropout])

# Add classification layer
output_layer = Dense(num_classes, activation='softmax')(merged_output)

# Create the model
model = Model(inputs=[input_scalar, input_sequence], outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 100
batch_size = 128

# Train the model
history = model.fit([scalar_X_train_pca, X_sequence_train_padded_transposed], y_train,
          validation_data=([scalar_X_val_pca, X_sequence_val_padded_transposed], y_val),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 15s 2s/step - loss: 5.7089 - accuracy: 0.0617 - val_loss: 5.2860 - val_accuracy: 0.1017
# Epoch 2/100
# 8/8 [==============================] - 5s 690ms/step - loss: 5.2074 - accuracy: 0.1245 - val_loss: 4.9813 - val_accuracy: 0.2246
# Epoch 3/100
# 8/8 [==============================] - 5s 691ms/step - loss: 4.8895 - accuracy: 0.2032 - val_loss: 4.7463 - val_accuracy: 0.2627
# Epoch 4/100
# 8/8 [==============================] - 5s 690ms/step - loss: 4.6371 - accuracy: 0.2628 - val_loss: 4.5342 - val_accuracy: 0.3390
# Epoch 5/100
# 8/8 [==============================] - 5s 690ms/step - loss: 4.4065 - accuracy: 0.3191 - val_loss: 4.3260 - val_accuracy: 0.4364
# Epoch 6/100
# 8/8 [==============================] - 5s 692ms/step - loss: 4.1534 - accuracy: 0.3819 - val_loss: 4.1231 - val_accuracy: 0.4873
# Epoch 7/100
# 8/8 [==============================] - 5s 689ms/step - loss: 3.9953 - accuracy: 0.4074 - val_loss: 3.9313 - val_accuracy: 0.4746
# Epoch 8/100
# 8/8 [==============================] - 5s 697ms/step - loss: 3.7719 - accuracy: 0.4489 - val_loss: 3.7674 - val_accuracy: 0.5424
# Epoch 9/100
# 8/8 [==============================] - 5s 695ms/step - loss: 3.6231 - accuracy: 0.4957 - val_loss: 3.6203 - val_accuracy: 0.5932
# Epoch 10/100
# 8/8 [==============================] - 5s 689ms/step - loss: 3.4304 - accuracy: 0.5383 - val_loss: 3.4958 - val_accuracy: 0.5932
# Epoch 11/100
# 8/8 [==============================] - 5s 690ms/step - loss: 3.2941 - accuracy: 0.5309 - val_loss: 3.3676 - val_accuracy: 0.5890
# Epoch 12/100
# 8/8 [==============================] - 5s 691ms/step - loss: 3.1442 - accuracy: 0.5660 - val_loss: 3.2444 - val_accuracy: 0.6271
# Epoch 13/100
# 8/8 [==============================] - 5s 693ms/step - loss: 3.0599 - accuracy: 0.5968 - val_loss: 3.1339 - val_accuracy: 0.6271
# Epoch 14/100
# 8/8 [==============================] - 5s 692ms/step - loss: 2.9324 - accuracy: 0.6191 - val_loss: 3.0335 - val_accuracy: 0.6441
# Epoch 15/100
# 8/8 [==============================] - 5s 690ms/step - loss: 2.8170 - accuracy: 0.6468 - val_loss: 2.9471 - val_accuracy: 0.6356
# Epoch 16/100
# 8/8 [==============================] - 5s 694ms/step - loss: 2.7233 - accuracy: 0.6660 - val_loss: 2.8572 - val_accuracy: 0.6483
# Epoch 17/100
# 8/8 [==============================] - 5s 689ms/step - loss: 2.6314 - accuracy: 0.6798 - val_loss: 2.7928 - val_accuracy: 0.6653
# Epoch 18/100
# 8/8 [==============================] - 5s 693ms/step - loss: 2.5328 - accuracy: 0.6936 - val_loss: 2.7258 - val_accuracy: 0.6907
# Epoch 19/100
# 8/8 [==============================] - 5s 690ms/step - loss: 2.4692 - accuracy: 0.6957 - val_loss: 2.6630 - val_accuracy: 0.6949
# Epoch 20/100
# 8/8 [==============================] - 5s 699ms/step - loss: 2.4287 - accuracy: 0.7085 - val_loss: 2.6079 - val_accuracy: 0.6822
# Epoch 21/100
# 8/8 [==============================] - 5s 693ms/step - loss: 2.3326 - accuracy: 0.7191 - val_loss: 2.5341 - val_accuracy: 0.6949
# Epoch 22/100
# 8/8 [==============================] - 5s 692ms/step - loss: 2.2811 - accuracy: 0.7309 - val_loss: 2.4667 - val_accuracy: 0.6949
# Epoch 23/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.2398 - accuracy: 0.7394 - val_loss: 2.4231 - val_accuracy: 0.7203
# Epoch 24/100
# 8/8 [==============================] - 5s 690ms/step - loss: 2.1512 - accuracy: 0.7596 - val_loss: 2.3795 - val_accuracy: 0.7203
# Epoch 25/100
# 8/8 [==============================] - 5s 691ms/step - loss: 2.1193 - accuracy: 0.7660 - val_loss: 2.3257 - val_accuracy: 0.7161
# Epoch 26/100
# 8/8 [==============================] - 5s 693ms/step - loss: 2.0877 - accuracy: 0.7617 - val_loss: 2.2728 - val_accuracy: 0.7288
# Epoch 27/100
# 8/8 [==============================] - 5s 692ms/step - loss: 2.0648 - accuracy: 0.7574 - val_loss: 2.2295 - val_accuracy: 0.7246
# Epoch 28/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.9951 - accuracy: 0.7798 - val_loss: 2.1932 - val_accuracy: 0.7203
# Epoch 29/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.9320 - accuracy: 0.8053 - val_loss: 2.1629 - val_accuracy: 0.7415
# Epoch 30/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.9107 - accuracy: 0.7904 - val_loss: 2.1405 - val_accuracy: 0.7288
# Epoch 31/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.8934 - accuracy: 0.7904 - val_loss: 2.1016 - val_accuracy: 0.7373
# Epoch 32/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.8595 - accuracy: 0.7947 - val_loss: 2.0702 - val_accuracy: 0.7458
# Epoch 33/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.8248 - accuracy: 0.8096 - val_loss: 2.0615 - val_accuracy: 0.7288
# Epoch 34/100
# 8/8 [==============================] - 5s 697ms/step - loss: 1.8078 - accuracy: 0.8064 - val_loss: 2.0495 - val_accuracy: 0.7288
# Epoch 35/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.7500 - accuracy: 0.8170 - val_loss: 2.0264 - val_accuracy: 0.7542
# Epoch 36/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.7355 - accuracy: 0.8170 - val_loss: 2.0029 - val_accuracy: 0.7415
# Epoch 37/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.6865 - accuracy: 0.8298 - val_loss: 1.9816 - val_accuracy: 0.7415
# Epoch 38/100
# 8/8 [==============================] - 5s 698ms/step - loss: 1.6952 - accuracy: 0.8106 - val_loss: 1.9511 - val_accuracy: 0.7500
# Epoch 39/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.6857 - accuracy: 0.8128 - val_loss: 1.9495 - val_accuracy: 0.7331
# Epoch 40/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.6364 - accuracy: 0.8404 - val_loss: 1.9279 - val_accuracy: 0.7627
# Epoch 41/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.5969 - accuracy: 0.8362 - val_loss: 1.8933 - val_accuracy: 0.7712
# Epoch 42/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.5906 - accuracy: 0.8394 - val_loss: 1.8557 - val_accuracy: 0.7754
# Epoch 43/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.5871 - accuracy: 0.8394 - val_loss: 1.8298 - val_accuracy: 0.7627
# Epoch 44/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.5363 - accuracy: 0.8489 - val_loss: 1.8213 - val_accuracy: 0.7585
# Epoch 45/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.5689 - accuracy: 0.8223 - val_loss: 1.8037 - val_accuracy: 0.7966
# Epoch 46/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.5247 - accuracy: 0.8511 - val_loss: 1.7934 - val_accuracy: 0.7754
# Epoch 47/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.5181 - accuracy: 0.8362 - val_loss: 1.7932 - val_accuracy: 0.7627
# Epoch 48/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.4955 - accuracy: 0.8479 - val_loss: 1.7792 - val_accuracy: 0.7669
# Epoch 49/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.4572 - accuracy: 0.8585 - val_loss: 1.7654 - val_accuracy: 0.7754
# Epoch 50/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.4732 - accuracy: 0.8585 - val_loss: 1.7630 - val_accuracy: 0.7797
# Epoch 51/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.4397 - accuracy: 0.8500 - val_loss: 1.7827 - val_accuracy: 0.7669
# Epoch 52/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.4148 - accuracy: 0.8691 - val_loss: 1.7602 - val_accuracy: 0.7754
# Epoch 53/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.4034 - accuracy: 0.8649 - val_loss: 1.7404 - val_accuracy: 0.7797
# Epoch 54/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.4040 - accuracy: 0.8574 - val_loss: 1.7133 - val_accuracy: 0.7839
# Epoch 55/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.3850 - accuracy: 0.8649 - val_loss: 1.6821 - val_accuracy: 0.7754
# Epoch 56/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.3860 - accuracy: 0.8660 - val_loss: 1.6508 - val_accuracy: 0.7924
# Epoch 57/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.3529 - accuracy: 0.8766 - val_loss: 1.6351 - val_accuracy: 0.7839
# Epoch 58/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.3233 - accuracy: 0.8819 - val_loss: 1.6076 - val_accuracy: 0.7966
# Epoch 59/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.3375 - accuracy: 0.8734 - val_loss: 1.6022 - val_accuracy: 0.7966
# Epoch 60/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.3350 - accuracy: 0.8691 - val_loss: 1.6053 - val_accuracy: 0.7966
# Epoch 61/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.3155 - accuracy: 0.8766 - val_loss: 1.5950 - val_accuracy: 0.7966
# Epoch 62/100
# 8/8 [==============================] - 5s 696ms/step - loss: 1.2832 - accuracy: 0.8830 - val_loss: 1.5817 - val_accuracy: 0.7924
# Epoch 63/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.2738 - accuracy: 0.8872 - val_loss: 1.5751 - val_accuracy: 0.7924
# Epoch 64/100
# 8/8 [==============================] - 5s 695ms/step - loss: 1.2737 - accuracy: 0.8926 - val_loss: 1.5449 - val_accuracy: 0.7881
# Epoch 65/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2769 - accuracy: 0.8777 - val_loss: 1.5353 - val_accuracy: 0.7839
# Epoch 66/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.2558 - accuracy: 0.8840 - val_loss: 1.5211 - val_accuracy: 0.7966
# Epoch 67/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2422 - accuracy: 0.8904 - val_loss: 1.5077 - val_accuracy: 0.7797
# Epoch 68/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2496 - accuracy: 0.8660 - val_loss: 1.5065 - val_accuracy: 0.7881
# Epoch 69/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.2289 - accuracy: 0.8894 - val_loss: 1.4912 - val_accuracy: 0.7966
# Epoch 70/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.2308 - accuracy: 0.8798 - val_loss: 1.4639 - val_accuracy: 0.7966
# Epoch 71/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.2272 - accuracy: 0.8787 - val_loss: 1.4531 - val_accuracy: 0.7924
# Epoch 72/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.1943 - accuracy: 0.8851 - val_loss: 1.4487 - val_accuracy: 0.7881
# Epoch 73/100
# 8/8 [==============================] - 6s 697ms/step - loss: 1.1767 - accuracy: 0.9011 - val_loss: 1.4357 - val_accuracy: 0.7966
# Epoch 74/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.2016 - accuracy: 0.8883 - val_loss: 1.4183 - val_accuracy: 0.7881
# Epoch 75/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.1888 - accuracy: 0.8755 - val_loss: 1.4133 - val_accuracy: 0.7881
# Epoch 76/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1586 - accuracy: 0.9021 - val_loss: 1.3732 - val_accuracy: 0.8093
# Epoch 77/100
# 8/8 [==============================] - 5s 697ms/step - loss: 1.1690 - accuracy: 0.8915 - val_loss: 1.3686 - val_accuracy: 0.7754
# Epoch 78/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.1401 - accuracy: 0.8989 - val_loss: 1.3719 - val_accuracy: 0.7966
# Epoch 79/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.1444 - accuracy: 0.9032 - val_loss: 1.3600 - val_accuracy: 0.7966
# Epoch 80/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1141 - accuracy: 0.9011 - val_loss: 1.3550 - val_accuracy: 0.8008
# Epoch 81/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1116 - accuracy: 0.9053 - val_loss: 1.3537 - val_accuracy: 0.7924
# Epoch 82/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.1318 - accuracy: 0.8894 - val_loss: 1.3580 - val_accuracy: 0.7754
# Epoch 83/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.1105 - accuracy: 0.9096 - val_loss: 1.3541 - val_accuracy: 0.7797
# Epoch 84/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.0771 - accuracy: 0.9181 - val_loss: 1.3567 - val_accuracy: 0.7924
# Epoch 85/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.1078 - accuracy: 0.8926 - val_loss: 1.3804 - val_accuracy: 0.7966
# Epoch 86/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.0747 - accuracy: 0.9223 - val_loss: 1.3979 - val_accuracy: 0.7839
# Epoch 87/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.0906 - accuracy: 0.8957 - val_loss: 1.3847 - val_accuracy: 0.7754
# Epoch 88/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.0817 - accuracy: 0.8979 - val_loss: 1.3590 - val_accuracy: 0.8008
# Epoch 89/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.0733 - accuracy: 0.9106 - val_loss: 1.3434 - val_accuracy: 0.7966
# Epoch 90/100
# 8/8 [==============================] - 5s 694ms/step - loss: 1.0683 - accuracy: 0.9117 - val_loss: 1.3316 - val_accuracy: 0.7924
# Epoch 91/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.0532 - accuracy: 0.9106 - val_loss: 1.3355 - val_accuracy: 0.7966
# Epoch 92/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.0387 - accuracy: 0.9213 - val_loss: 1.3322 - val_accuracy: 0.7839
# Epoch 93/100
# 8/8 [==============================] - 5s 691ms/step - loss: 1.0566 - accuracy: 0.9032 - val_loss: 1.3170 - val_accuracy: 0.7881
# Epoch 94/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.0187 - accuracy: 0.9234 - val_loss: 1.2868 - val_accuracy: 0.7881
# Epoch 95/100
# 8/8 [==============================] - 5s 692ms/step - loss: 1.0362 - accuracy: 0.9053 - val_loss: 1.2955 - val_accuracy: 0.7881
# Epoch 96/100
# 8/8 [==============================] - 5s 690ms/step - loss: 1.0289 - accuracy: 0.9138 - val_loss: 1.2838 - val_accuracy: 0.7839
# Epoch 97/100
# 8/8 [==============================] - 5s 693ms/step - loss: 1.0151 - accuracy: 0.9255 - val_loss: 1.2683 - val_accuracy: 0.7966
# Epoch 98/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.0148 - accuracy: 0.9149 - val_loss: 1.3187 - val_accuracy: 0.8008
# Epoch 99/100
# 8/8 [==============================] - 5s 689ms/step - loss: 1.0147 - accuracy: 0.9096 - val_loss: 1.3492 - val_accuracy: 0.8051
# Epoch 100/100
# 8/8 [==============================] - 5s 690ms/step - loss: 0.9997 - accuracy: 0.9128 - val_loss: 1.3284 - val_accuracy: 0.8051

# %%
from keras.utils import plot_model
# !pip install networkx
from IPython.display import Image, display

# Generate the plot
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# Display the image in the notebook
display(Image(filename='model.png'))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# Evaluate the model on the validation set
y_val_pred = model.predict([scalar_X_val_pca, X_sequence_val_padded_transposed])
y_val_pred_classes = np.argmax(y_val_pred, axis=1)  # Convert probabilities to class labels

y_val_true_classes = np.argmax(y_val, axis=1)  # Convert one-hot encoded labels to class labels

# Calculate metrics
accuracy = accuracy_score(y_val_true_classes, y_val_pred_classes)
precision = precision_score(y_val_true_classes, y_val_pred_classes, average='weighted')
recall = recall_score(y_val_true_classes, y_val_pred_classes, average='weighted')
f1 = f1_score(y_val_true_classes, y_val_pred_classes, average='weighted')

print("Validation Set Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")


# Dual-Axis plot to visualise training-validation loss and accuracy.
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color=color)
trainloss_line, = ax1.plot(history.history['loss'], color=color, label='Train Loss')
valloss_line, = ax1.plot(history.history['val_loss'], color=color, linestyle='dashed', label='Val Loss')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Accuracy', color=color)
trainacc_line, = ax2.plot(history.history['accuracy'], color=color, label='Train Acc')
valacc_line, = ax2.plot(history.history['val_accuracy'], color=color, linestyle='dashed', label='Val Acc')
ax2.tick_params(axis='y', labelcolor=color)

lns = [trainloss_line, valloss_line, trainacc_line, valacc_line]
ax1.legend(handles=lns, loc='center right')

fig.tight_layout()
plt.show()

# Make predictions using the trained model
y_pred = model.predict([scalar_X_val_pca, X_sequence_val_padded_transposed])

# Convert the one-hot encoded predictions back to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_val, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)

# Plot the confusion matrix
classes = ['activity' + str(x+1) for x in range(0, 21)]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='viridis', values_format='d')

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(rotation=90)
plt.show()

print("y_val", y_val.shape)
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# 8/8 [==============================] - 2s 221ms/step
# Validation Set Metrics:
# Accuracy: 0.8051
# Precision: 0.8155
# Recall: 0.8051
# F1-Score: 0.8017
# 8/8 [==============================] - 2s 221ms/step
# y_val (236, 21)

# %% [markdown]
# Additional RNN Layer added

# %%
from keras.regularizers import l1_l2

# Define the number of classes
num_classes = y_train.shape[1]

# Regularization hyperparameters
l1_lambda = 0.002
l2_lambda = 0.002

# Create FNN for scalar features
input_scalar = Input(shape=(scalar_X_train_pca.shape[1],))
dense_layer_1 = Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(input_scalar)
dense_layer_2 = Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(dense_layer_1)

# Transpose the sequence data to match the expected shape
X_sequence_train_padded_transposed = np.transpose(X_sequence_train_padded, (0, 2, 1))
X_sequence_val_padded_transposed = np.transpose(X_sequence_val_padded, (0, 2, 1))

# Create RNN for sequence data
input_sequence = Input(shape=(max_sequence_length, non_scalar_X_train.shape[1]))

# First LSTM Layer
rnn_layer_1 = LSTM(128, return_sequences=True)(input_sequence)

# Second LSTM Layer
rnn_layer_2 = LSTM(64)(rnn_layer_1)


# After dense_layer_2 and rnn_layer
dense_layer_dropout = Dropout(0.5)(dense_layer_2)
rnn_layer_dropout = Dropout(0.5)(rnn_layer_2)

# Merge the outputs of FNN and RNN with dropout
merged_output = concatenate([dense_layer_dropout, rnn_layer_dropout])

# Add classification layer
output_layer = Dense(num_classes, activation='softmax')(merged_output)

# Create the model
model = Model(inputs=[input_scalar, input_sequence], outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 100
batch_size = 128

# Train the model
history = model.fit([scalar_X_train_pca, X_sequence_train_padded_transposed], y_train,
          validation_data=([scalar_X_val_pca, X_sequence_val_padded_transposed], y_val),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 15s 1s/step - loss: 8.1425 - accuracy: 0.0617 - val_loss: 7.5018 - val_accuracy: 0.1695
# Epoch 2/100
# 8/8 [==============================] - 10s 1s/step - loss: 7.4425 - accuracy: 0.1138 - val_loss: 7.1068 - val_accuracy: 0.2585
# Epoch 3/100
# 8/8 [==============================] - 10s 1s/step - loss: 7.0955 - accuracy: 0.1745 - val_loss: 6.7651 - val_accuracy: 0.2924
# Epoch 4/100
# 8/8 [==============================] - 10s 1s/step - loss: 6.7048 - accuracy: 0.2372 - val_loss: 6.4332 - val_accuracy: 0.3856
# Epoch 5/100
# 8/8 [==============================] - 10s 1s/step - loss: 6.3299 - accuracy: 0.2894 - val_loss: 6.0992 - val_accuracy: 0.4619
# Epoch 6/100
# 8/8 [==============================] - 10s 1s/step - loss: 5.9684 - accuracy: 0.3606 - val_loss: 5.7697 - val_accuracy: 0.4873
# Epoch 7/100
# 8/8 [==============================] - 10s 1s/step - loss: 5.7003 - accuracy: 0.3840 - val_loss: 5.4743 - val_accuracy: 0.5127
# Epoch 8/100
# 8/8 [==============================] - 10s 1s/step - loss: 5.3734 - accuracy: 0.4479 - val_loss: 5.1873 - val_accuracy: 0.5593
# Epoch 9/100
# 8/8 [==============================] - 10s 1s/step - loss: 5.1003 - accuracy: 0.4489 - val_loss: 4.9256 - val_accuracy: 0.5805
# Epoch 10/100
# 8/8 [==============================] - 10s 1s/step - loss: 4.8718 - accuracy: 0.4979 - val_loss: 4.7045 - val_accuracy: 0.5636
# Epoch 11/100
# 8/8 [==============================] - 10s 1s/step - loss: 4.5934 - accuracy: 0.5340 - val_loss: 4.4927 - val_accuracy: 0.6144
# Epoch 12/100
# 8/8 [==============================] - 10s 1s/step - loss: 4.4159 - accuracy: 0.5521 - val_loss: 4.3057 - val_accuracy: 0.6441
# Epoch 13/100
# 8/8 [==============================] - 10s 1s/step - loss: 4.1843 - accuracy: 0.5777 - val_loss: 4.1200 - val_accuracy: 0.6229
# Epoch 14/100
# 8/8 [==============================] - 10s 1s/step - loss: 4.0224 - accuracy: 0.5936 - val_loss: 3.9459 - val_accuracy: 0.6356
# Epoch 15/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.8426 - accuracy: 0.6085 - val_loss: 3.7913 - val_accuracy: 0.6568
# Epoch 16/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.6603 - accuracy: 0.6298 - val_loss: 3.6510 - val_accuracy: 0.6653
# Epoch 17/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.5370 - accuracy: 0.6521 - val_loss: 3.5137 - val_accuracy: 0.6610
# Epoch 18/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.3709 - accuracy: 0.6734 - val_loss: 3.3941 - val_accuracy: 0.7034
# Epoch 19/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.2934 - accuracy: 0.6574 - val_loss: 3.2820 - val_accuracy: 0.6864
# Epoch 20/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.2141 - accuracy: 0.6617 - val_loss: 3.1757 - val_accuracy: 0.6907
# Epoch 21/100
# 8/8 [==============================] - 10s 1s/step - loss: 3.0636 - accuracy: 0.6755 - val_loss: 3.0851 - val_accuracy: 0.7034
# Epoch 22/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.9776 - accuracy: 0.6989 - val_loss: 2.9975 - val_accuracy: 0.7119
# Epoch 23/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.8810 - accuracy: 0.7053 - val_loss: 2.9100 - val_accuracy: 0.6992
# Epoch 24/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.7969 - accuracy: 0.7160 - val_loss: 2.8345 - val_accuracy: 0.7161
# Epoch 25/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.7454 - accuracy: 0.7138 - val_loss: 2.7683 - val_accuracy: 0.7203
# Epoch 26/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.6728 - accuracy: 0.7149 - val_loss: 2.6977 - val_accuracy: 0.7076
# Epoch 27/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.5753 - accuracy: 0.7074 - val_loss: 2.6301 - val_accuracy: 0.7161
# Epoch 28/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.5300 - accuracy: 0.7287 - val_loss: 2.5669 - val_accuracy: 0.7203
# Epoch 29/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.4708 - accuracy: 0.7404 - val_loss: 2.5125 - val_accuracy: 0.7203
# Epoch 30/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.4203 - accuracy: 0.7457 - val_loss: 2.4625 - val_accuracy: 0.7246
# Epoch 31/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.3840 - accuracy: 0.7404 - val_loss: 2.4174 - val_accuracy: 0.7203
# Epoch 32/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.3336 - accuracy: 0.7330 - val_loss: 2.3720 - val_accuracy: 0.7246
# Epoch 33/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.2605 - accuracy: 0.7606 - val_loss: 2.3340 - val_accuracy: 0.7415
# Epoch 34/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.2661 - accuracy: 0.7319 - val_loss: 2.3062 - val_accuracy: 0.7288
# Epoch 35/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.2050 - accuracy: 0.7383 - val_loss: 2.2573 - val_accuracy: 0.7288
# Epoch 36/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.1714 - accuracy: 0.7479 - val_loss: 2.2313 - val_accuracy: 0.7458
# Epoch 37/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.1488 - accuracy: 0.7372 - val_loss: 2.1968 - val_accuracy: 0.7415
# Epoch 38/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.0980 - accuracy: 0.7436 - val_loss: 2.1669 - val_accuracy: 0.7331
# Epoch 39/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.0919 - accuracy: 0.7511 - val_loss: 2.1407 - val_accuracy: 0.7373
# Epoch 40/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.0256 - accuracy: 0.7660 - val_loss: 2.1113 - val_accuracy: 0.7288
# Epoch 41/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.0155 - accuracy: 0.7628 - val_loss: 2.0736 - val_accuracy: 0.7500
# Epoch 42/100
# 8/8 [==============================] - 10s 1s/step - loss: 2.0105 - accuracy: 0.7404 - val_loss: 2.0417 - val_accuracy: 0.7458
# Epoch 43/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.9467 - accuracy: 0.7819 - val_loss: 2.0225 - val_accuracy: 0.7373
# Epoch 44/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.9183 - accuracy: 0.7883 - val_loss: 1.9960 - val_accuracy: 0.7500
# Epoch 45/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.8962 - accuracy: 0.7702 - val_loss: 1.9772 - val_accuracy: 0.7458
# Epoch 46/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.8746 - accuracy: 0.7691 - val_loss: 1.9558 - val_accuracy: 0.7669
# Epoch 47/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.8763 - accuracy: 0.7670 - val_loss: 1.9269 - val_accuracy: 0.7458
# Epoch 48/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.8183 - accuracy: 0.7894 - val_loss: 1.9075 - val_accuracy: 0.7415
# Epoch 49/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.8195 - accuracy: 0.7745 - val_loss: 1.8900 - val_accuracy: 0.7458
# Epoch 50/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.8192 - accuracy: 0.7638 - val_loss: 1.8757 - val_accuracy: 0.7458
# Epoch 51/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.7533 - accuracy: 0.7936 - val_loss: 1.8567 - val_accuracy: 0.7373
# Epoch 52/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.7684 - accuracy: 0.7691 - val_loss: 1.8394 - val_accuracy: 0.7627
# Epoch 53/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.7535 - accuracy: 0.7766 - val_loss: 1.8181 - val_accuracy: 0.7542
# Epoch 54/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.7143 - accuracy: 0.7713 - val_loss: 1.8005 - val_accuracy: 0.7373
# Epoch 55/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.7340 - accuracy: 0.7702 - val_loss: 1.7860 - val_accuracy: 0.7500
# Epoch 56/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6782 - accuracy: 0.7926 - val_loss: 1.7744 - val_accuracy: 0.7627
# Epoch 57/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6924 - accuracy: 0.7766 - val_loss: 1.7634 - val_accuracy: 0.7585
# Epoch 58/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6473 - accuracy: 0.8000 - val_loss: 1.7534 - val_accuracy: 0.7458
# Epoch 59/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6473 - accuracy: 0.8000 - val_loss: 1.7318 - val_accuracy: 0.7627
# Epoch 60/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6307 - accuracy: 0.7872 - val_loss: 1.7128 - val_accuracy: 0.7627
# Epoch 61/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6237 - accuracy: 0.7926 - val_loss: 1.7055 - val_accuracy: 0.7712
# Epoch 62/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.6094 - accuracy: 0.8000 - val_loss: 1.6961 - val_accuracy: 0.7627
# Epoch 63/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5910 - accuracy: 0.7809 - val_loss: 1.6915 - val_accuracy: 0.7585
# Epoch 64/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5681 - accuracy: 0.8043 - val_loss: 1.6821 - val_accuracy: 0.7542
# Epoch 65/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5749 - accuracy: 0.7872 - val_loss: 1.6673 - val_accuracy: 0.7585
# Epoch 66/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5574 - accuracy: 0.7947 - val_loss: 1.6514 - val_accuracy: 0.7415
# Epoch 67/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5437 - accuracy: 0.7957 - val_loss: 1.6426 - val_accuracy: 0.7797
# Epoch 68/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5390 - accuracy: 0.8000 - val_loss: 1.6292 - val_accuracy: 0.7797
# Epoch 69/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5276 - accuracy: 0.7915 - val_loss: 1.6234 - val_accuracy: 0.7627
# Epoch 70/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4970 - accuracy: 0.8074 - val_loss: 1.6064 - val_accuracy: 0.7627
# Epoch 71/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.5103 - accuracy: 0.7968 - val_loss: 1.5980 - val_accuracy: 0.7712
# Epoch 72/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4722 - accuracy: 0.8021 - val_loss: 1.5980 - val_accuracy: 0.7627
# Epoch 73/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4382 - accuracy: 0.8202 - val_loss: 1.5781 - val_accuracy: 0.7712
# Epoch 74/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4638 - accuracy: 0.8000 - val_loss: 1.5766 - val_accuracy: 0.7712
# Epoch 75/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4471 - accuracy: 0.8170 - val_loss: 1.5615 - val_accuracy: 0.7669
# Epoch 76/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4312 - accuracy: 0.8319 - val_loss: 1.5457 - val_accuracy: 0.7627
# Epoch 77/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4060 - accuracy: 0.8223 - val_loss: 1.5425 - val_accuracy: 0.7712
# Epoch 78/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4028 - accuracy: 0.8277 - val_loss: 1.5313 - val_accuracy: 0.7712
# Epoch 79/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.4244 - accuracy: 0.7979 - val_loss: 1.5252 - val_accuracy: 0.7797
# Epoch 80/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3962 - accuracy: 0.8277 - val_loss: 1.5251 - val_accuracy: 0.7754
# Epoch 81/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3795 - accuracy: 0.8191 - val_loss: 1.5133 - val_accuracy: 0.7797
# Epoch 82/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3497 - accuracy: 0.8234 - val_loss: 1.5103 - val_accuracy: 0.7500
# Epoch 83/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3806 - accuracy: 0.8138 - val_loss: 1.5066 - val_accuracy: 0.7797
# Epoch 84/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3695 - accuracy: 0.8149 - val_loss: 1.4962 - val_accuracy: 0.7627
# Epoch 85/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3423 - accuracy: 0.8309 - val_loss: 1.4801 - val_accuracy: 0.7797
# Epoch 86/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3051 - accuracy: 0.8479 - val_loss: 1.4757 - val_accuracy: 0.7797
# Epoch 87/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3199 - accuracy: 0.8457 - val_loss: 1.4761 - val_accuracy: 0.7669
# Epoch 88/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3208 - accuracy: 0.8213 - val_loss: 1.4686 - val_accuracy: 0.7712
# Epoch 89/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2965 - accuracy: 0.8330 - val_loss: 1.4632 - val_accuracy: 0.7585
# Epoch 90/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.3129 - accuracy: 0.8191 - val_loss: 1.4546 - val_accuracy: 0.7712
# Epoch 91/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2859 - accuracy: 0.8521 - val_loss: 1.4529 - val_accuracy: 0.7754
# Epoch 92/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2747 - accuracy: 0.8340 - val_loss: 1.4509 - val_accuracy: 0.7669
# Epoch 93/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2764 - accuracy: 0.8223 - val_loss: 1.4353 - val_accuracy: 0.7712
# Epoch 94/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2647 - accuracy: 0.8426 - val_loss: 1.4295 - val_accuracy: 0.7627
# Epoch 95/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2691 - accuracy: 0.8298 - val_loss: 1.4238 - val_accuracy: 0.7839
# Epoch 96/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2619 - accuracy: 0.8330 - val_loss: 1.4177 - val_accuracy: 0.7881
# Epoch 97/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2495 - accuracy: 0.8383 - val_loss: 1.4194 - val_accuracy: 0.7669
# Epoch 98/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2237 - accuracy: 0.8457 - val_loss: 1.4225 - val_accuracy: 0.7669
# Epoch 99/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2559 - accuracy: 0.8298 - val_loss: 1.4151 - val_accuracy: 0.7712
# Epoch 100/100
# 8/8 [==============================] - 10s 1s/step - loss: 1.2249 - accuracy: 0.8479 - val_loss: 1.4051 - val_accuracy: 0.7712

# %%
from keras.utils import plot_model
# !pip install networkx
from IPython.display import Image, display

# Generate the model flowchart
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# Display the image in the notebook
display(Image(filename='model.png'))


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Evaluate the model on the validation set
y_val_pred = model.predict([scalar_X_val_pca, X_sequence_val_padded_transposed])
y_val_pred_classes = np.argmax(y_val_pred, axis=1)  # Convert probabilities to class labels

y_val_true_classes = np.argmax(y_val, axis=1)  # Convert one-hot encoded labels to class labels

# Calculate metrics
accuracy = accuracy_score(y_val_true_classes, y_val_pred_classes)
precision = precision_score(y_val_true_classes, y_val_pred_classes, average='weighted')
recall = recall_score(y_val_true_classes, y_val_pred_classes, average='weighted')
f1 = f1_score(y_val_true_classes, y_val_pred_classes, average='weighted')

print("Validation Set Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")



# Dual-Axis plot to visualise training-validation loss and accuracy.
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color=color)
trainloss_line, = ax1.plot(history.history['loss'], color=color, label='Train Loss')
valloss_line, = ax1.plot(history.history['val_loss'], color=color, linestyle='dashed', label='Val Loss')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Accuracy', color=color)
trainacc_line, = ax2.plot(history.history['accuracy'], color=color, label='Train Acc')
valacc_line, = ax2.plot(history.history['val_accuracy'], color=color, linestyle='dashed', label='Val Acc')
ax2.tick_params(axis='y', labelcolor=color)

lns = [trainloss_line, valloss_line, trainacc_line, valacc_line]
ax1.legend(handles=lns, loc='center right')

fig.tight_layout()
plt.show()


# Make predictions using the trained model
y_pred = model.predict([scalar_X_val_pca, X_sequence_val_padded_transposed])

# Convert the one-hot encoded predictions back to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_val, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)

# Plot the confusion matrix
classes = ['activity' + str(x+1) for x in range(0, 21)]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='viridis', values_format='d')

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(rotation=90)
plt.show()

print("y_val", y_val.shape)
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# 8/8 [==============================] - 4s 430ms/step
# Validation Set Metrics:
# Accuracy: 0.7712
# Precision: 0.7784
# Recall: 0.7712
# F1-Score: 0.7653
# 8/8 [==============================] - 3s 428ms/step
# y_val (236, 21)

# %% [markdown]
# Additional Dense layer before the final classification layer.

# %%
from keras.regularizers import l1_l2

# Define the number of classes
num_classes = y_train.shape[1]

# Regularization hyperparameters
l1_lambda = 0.002  # L1 regularization hyperparameter
l2_lambda = 0.002  # L2 regularization hyperparameter

# Create FNN for scalar features
input_scalar = Input(shape=(scalar_X_train_pca.shape[1],))
dense_layer_1 = Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(input_scalar)
dense_layer_2 = Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=l1_lambda, l2=l2_lambda))(dense_layer_1)

# Transpose the sequence data to match the expected shape
X_sequence_train_padded_transposed = np.transpose(X_sequence_train_padded, (0, 2, 1))
X_sequence_val_padded_transposed = np.transpose(X_sequence_val_padded, (0, 2, 1))

# Create RNN for sequence data
input_sequence = Input(shape=(max_sequence_length, non_scalar_X_train.shape[1]))

# First LSTM Layer
rnn_layer_1 = LSTM(64, return_sequences=True)(input_sequence)

# Second LSTM Layer
rnn_layer_2 = LSTM(32)(rnn_layer_1)

# Add Dropout layers after both Second RNN and Second FNN Layers:
dense_layer_dropout = Dropout(0.5)(dense_layer_2)
rnn_layer_dropout = Dropout(0.5)(rnn_layer_2)

# Merge the outputs of FNN and RNN after dropout layers
merged_output = concatenate([dense_layer_dropout, rnn_layer_dropout])

# Add an additional Dense layer
dense_layer_3 = Dense(32, activation='relu')(merged_output)

# Add classification layer
output_layer = Dense(num_classes, activation='softmax')(merged_output)

# Create the model
model = Model(inputs=[input_scalar, input_sequence], outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 100
batch_size = 64

# Train the model
history = model.fit([scalar_X_train_pca, X_sequence_train_padded_transposed], y_train,
          validation_data=([scalar_X_val_pca, X_sequence_val_padded_transposed], y_val),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 28s 1s/step - loss: 8.2654 - accuracy: 0.0691 - val_loss: 7.4334 - val_accuracy: 0.1695
# Epoch 2/100
# 15/15 [==============================] - 16s 1s/step - loss: 7.1888 - accuracy: 0.1862 - val_loss: 6.8462 - val_accuracy: 0.2797
# Epoch 3/100
# 15/15 [==============================] - 16s 1s/step - loss: 6.5992 - accuracy: 0.2702 - val_loss: 6.3343 - val_accuracy: 0.3983
# Epoch 4/100
# 15/15 [==============================] - 16s 1s/step - loss: 6.1104 - accuracy: 0.3447 - val_loss: 5.8695 - val_accuracy: 0.4873
# Epoch 5/100
# 15/15 [==============================] - 16s 1s/step - loss: 5.6753 - accuracy: 0.4064 - val_loss: 5.4592 - val_accuracy: 0.5254
# Epoch 6/100
# 15/15 [==============================] - 16s 1s/step - loss: 5.2656 - accuracy: 0.4681 - val_loss: 5.0702 - val_accuracy: 0.6017
# Epoch 7/100
# 15/15 [==============================] - 16s 1s/step - loss: 4.8792 - accuracy: 0.5309 - val_loss: 4.7392 - val_accuracy: 0.6144
# Epoch 8/100
# 15/15 [==============================] - 16s 1s/step - loss: 4.5889 - accuracy: 0.5564 - val_loss: 4.4433 - val_accuracy: 0.6314
# Epoch 9/100
# 15/15 [==============================] - 16s 1s/step - loss: 4.3064 - accuracy: 0.5691 - val_loss: 4.1880 - val_accuracy: 0.6568
# Epoch 10/100
# 15/15 [==============================] - 16s 1s/step - loss: 4.0293 - accuracy: 0.6234 - val_loss: 3.9650 - val_accuracy: 0.6525
# Epoch 11/100
# 15/15 [==============================] - 16s 1s/step - loss: 3.7900 - accuracy: 0.6436 - val_loss: 3.7826 - val_accuracy: 0.6907
# Epoch 12/100
# 15/15 [==============================] - 16s 1s/step - loss: 3.6099 - accuracy: 0.6511 - val_loss: 3.5978 - val_accuracy: 0.6949
# Epoch 13/100
# 15/15 [==============================] - 16s 1s/step - loss: 3.4187 - accuracy: 0.6564 - val_loss: 3.4123 - val_accuracy: 0.6949
# Epoch 14/100
# 15/15 [==============================] - 16s 1s/step - loss: 3.2548 - accuracy: 0.6713 - val_loss: 3.2518 - val_accuracy: 0.7076
# Epoch 15/100
# 15/15 [==============================] - 16s 1s/step - loss: 3.1308 - accuracy: 0.6755 - val_loss: 3.1249 - val_accuracy: 0.7119
# Epoch 16/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.9626 - accuracy: 0.7074 - val_loss: 2.9909 - val_accuracy: 0.7331
# Epoch 17/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.8947 - accuracy: 0.7011 - val_loss: 2.8892 - val_accuracy: 0.7331
# Epoch 18/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.7628 - accuracy: 0.7213 - val_loss: 2.7925 - val_accuracy: 0.7331
# Epoch 19/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.6765 - accuracy: 0.7213 - val_loss: 2.7032 - val_accuracy: 0.7119
# Epoch 20/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.5840 - accuracy: 0.7404 - val_loss: 2.6302 - val_accuracy: 0.7331
# Epoch 21/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.5274 - accuracy: 0.7191 - val_loss: 2.5405 - val_accuracy: 0.7415
# Epoch 22/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.4518 - accuracy: 0.7191 - val_loss: 2.4835 - val_accuracy: 0.7331
# Epoch 23/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.3873 - accuracy: 0.7351 - val_loss: 2.4161 - val_accuracy: 0.7458
# Epoch 24/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.3048 - accuracy: 0.7404 - val_loss: 2.3527 - val_accuracy: 0.7373
# Epoch 25/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.2566 - accuracy: 0.7447 - val_loss: 2.2936 - val_accuracy: 0.7458
# Epoch 26/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.2023 - accuracy: 0.7415 - val_loss: 2.2400 - val_accuracy: 0.7542
# Epoch 27/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.1594 - accuracy: 0.7596 - val_loss: 2.1812 - val_accuracy: 0.7500
# Epoch 28/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.1088 - accuracy: 0.7479 - val_loss: 2.1350 - val_accuracy: 0.7627
# Epoch 29/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.0425 - accuracy: 0.7745 - val_loss: 2.0980 - val_accuracy: 0.7585
# Epoch 30/100
# 15/15 [==============================] - 16s 1s/step - loss: 2.0206 - accuracy: 0.7628 - val_loss: 2.0475 - val_accuracy: 0.7627
# Epoch 31/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.9899 - accuracy: 0.7489 - val_loss: 2.0163 - val_accuracy: 0.7627
# Epoch 32/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.9441 - accuracy: 0.7564 - val_loss: 1.9980 - val_accuracy: 0.7585
# Epoch 33/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.8917 - accuracy: 0.7787 - val_loss: 1.9620 - val_accuracy: 0.7712
# Epoch 34/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.8725 - accuracy: 0.7809 - val_loss: 1.9285 - val_accuracy: 0.7754
# Epoch 35/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.8234 - accuracy: 0.8011 - val_loss: 1.8944 - val_accuracy: 0.7797
# Epoch 36/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.8223 - accuracy: 0.7830 - val_loss: 1.8662 - val_accuracy: 0.7924
# Epoch 37/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.7645 - accuracy: 0.7809 - val_loss: 1.8501 - val_accuracy: 0.7712
# Epoch 38/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.7705 - accuracy: 0.7713 - val_loss: 1.8258 - val_accuracy: 0.7839
# Epoch 39/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.7148 - accuracy: 0.8011 - val_loss: 1.8042 - val_accuracy: 0.7839
# Epoch 40/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.6711 - accuracy: 0.8000 - val_loss: 1.7642 - val_accuracy: 0.7754
# Epoch 41/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.6621 - accuracy: 0.8106 - val_loss: 1.7415 - val_accuracy: 0.7966
# Epoch 42/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.6518 - accuracy: 0.7947 - val_loss: 1.7236 - val_accuracy: 0.7924
# Epoch 43/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.6342 - accuracy: 0.7947 - val_loss: 1.7131 - val_accuracy: 0.7797
# Epoch 44/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.6257 - accuracy: 0.7968 - val_loss: 1.6979 - val_accuracy: 0.7797
# Epoch 45/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.5817 - accuracy: 0.8234 - val_loss: 1.6717 - val_accuracy: 0.7839
# Epoch 46/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.5707 - accuracy: 0.8085 - val_loss: 1.6710 - val_accuracy: 0.7881
# Epoch 47/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.5463 - accuracy: 0.8202 - val_loss: 1.6450 - val_accuracy: 0.7754
# Epoch 48/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.5082 - accuracy: 0.8181 - val_loss: 1.6300 - val_accuracy: 0.7924
# Epoch 49/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.5348 - accuracy: 0.8170 - val_loss: 1.6097 - val_accuracy: 0.7839
# Epoch 50/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.4933 - accuracy: 0.8234 - val_loss: 1.5862 - val_accuracy: 0.7924
# Epoch 51/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.4925 - accuracy: 0.8085 - val_loss: 1.5846 - val_accuracy: 0.7839
# Epoch 52/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.4572 - accuracy: 0.8223 - val_loss: 1.5652 - val_accuracy: 0.7924
# Epoch 53/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.4712 - accuracy: 0.8117 - val_loss: 1.5707 - val_accuracy: 0.7881
# Epoch 54/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.4384 - accuracy: 0.8106 - val_loss: 1.5546 - val_accuracy: 0.7881
# Epoch 55/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3969 - accuracy: 0.8351 - val_loss: 1.5528 - val_accuracy: 0.7839
# Epoch 56/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.4180 - accuracy: 0.8245 - val_loss: 1.5340 - val_accuracy: 0.7712
# Epoch 57/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3821 - accuracy: 0.8372 - val_loss: 1.5259 - val_accuracy: 0.8051
# Epoch 58/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3844 - accuracy: 0.8383 - val_loss: 1.5296 - val_accuracy: 0.7881
# Epoch 59/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3566 - accuracy: 0.8309 - val_loss: 1.5060 - val_accuracy: 0.7881
# Epoch 60/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3561 - accuracy: 0.8309 - val_loss: 1.5107 - val_accuracy: 0.7839
# Epoch 61/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3290 - accuracy: 0.8511 - val_loss: 1.5026 - val_accuracy: 0.7839
# Epoch 62/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3461 - accuracy: 0.8266 - val_loss: 1.5109 - val_accuracy: 0.7966
# Epoch 63/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.3125 - accuracy: 0.8404 - val_loss: 1.4901 - val_accuracy: 0.7712
# Epoch 64/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2926 - accuracy: 0.8574 - val_loss: 1.4904 - val_accuracy: 0.7924
# Epoch 65/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2986 - accuracy: 0.8447 - val_loss: 1.4835 - val_accuracy: 0.7966
# Epoch 66/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2883 - accuracy: 0.8479 - val_loss: 1.4644 - val_accuracy: 0.7966
# Epoch 67/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2457 - accuracy: 0.8617 - val_loss: 1.4587 - val_accuracy: 0.7839
# Epoch 68/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2362 - accuracy: 0.8489 - val_loss: 1.4522 - val_accuracy: 0.7881
# Epoch 69/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2244 - accuracy: 0.8617 - val_loss: 1.4289 - val_accuracy: 0.8051
# Epoch 70/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2381 - accuracy: 0.8404 - val_loss: 1.4306 - val_accuracy: 0.7924
# Epoch 71/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2178 - accuracy: 0.8660 - val_loss: 1.4148 - val_accuracy: 0.7966
# Epoch 72/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.2149 - accuracy: 0.8404 - val_loss: 1.4065 - val_accuracy: 0.7966
# Epoch 73/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1977 - accuracy: 0.8500 - val_loss: 1.4098 - val_accuracy: 0.8008
# Epoch 74/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1696 - accuracy: 0.8681 - val_loss: 1.4109 - val_accuracy: 0.8008
# Epoch 75/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1673 - accuracy: 0.8702 - val_loss: 1.4117 - val_accuracy: 0.7924
# Epoch 76/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1541 - accuracy: 0.8691 - val_loss: 1.3994 - val_accuracy: 0.8008
# Epoch 77/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1539 - accuracy: 0.8691 - val_loss: 1.3909 - val_accuracy: 0.8008
# Epoch 78/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1358 - accuracy: 0.8723 - val_loss: 1.3811 - val_accuracy: 0.7754
# Epoch 79/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1390 - accuracy: 0.8755 - val_loss: 1.3861 - val_accuracy: 0.7966
# Epoch 80/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1339 - accuracy: 0.8574 - val_loss: 1.3686 - val_accuracy: 0.8008
# Epoch 81/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1252 - accuracy: 0.8702 - val_loss: 1.3688 - val_accuracy: 0.8093
# Epoch 82/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1065 - accuracy: 0.8734 - val_loss: 1.3714 - val_accuracy: 0.8178
# Epoch 83/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.1115 - accuracy: 0.8670 - val_loss: 1.3636 - val_accuracy: 0.8008
# Epoch 84/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0970 - accuracy: 0.8681 - val_loss: 1.3666 - val_accuracy: 0.8008
# Epoch 85/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0590 - accuracy: 0.8968 - val_loss: 1.3705 - val_accuracy: 0.8051
# Epoch 86/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0774 - accuracy: 0.8947 - val_loss: 1.3684 - val_accuracy: 0.7966
# Epoch 87/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0858 - accuracy: 0.8734 - val_loss: 1.3599 - val_accuracy: 0.8093
# Epoch 88/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0693 - accuracy: 0.8872 - val_loss: 1.3639 - val_accuracy: 0.8051
# Epoch 89/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0457 - accuracy: 0.8809 - val_loss: 1.3743 - val_accuracy: 0.8136
# Epoch 90/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0656 - accuracy: 0.8777 - val_loss: 1.3939 - val_accuracy: 0.8136
# Epoch 91/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0365 - accuracy: 0.8872 - val_loss: 1.3654 - val_accuracy: 0.8093
# Epoch 92/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0274 - accuracy: 0.8979 - val_loss: 1.3536 - val_accuracy: 0.8220
# Epoch 93/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0496 - accuracy: 0.8766 - val_loss: 1.3622 - val_accuracy: 0.8347
# Epoch 94/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0212 - accuracy: 0.8862 - val_loss: 1.3615 - val_accuracy: 0.8136
# Epoch 95/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0362 - accuracy: 0.8851 - val_loss: 1.3720 - val_accuracy: 0.8136
# Epoch 96/100
# 15/15 [==============================] - 16s 1s/step - loss: 0.9943 - accuracy: 0.9074 - val_loss: 1.3678 - val_accuracy: 0.8305
# Epoch 97/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0252 - accuracy: 0.8862 - val_loss: 1.3581 - val_accuracy: 0.8305
# Epoch 98/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0106 - accuracy: 0.8947 - val_loss: 1.3866 - val_accuracy: 0.8008
# Epoch 99/100
# 15/15 [==============================] - 16s 1s/step - loss: 0.9982 - accuracy: 0.8936 - val_loss: 1.3613 - val_accuracy: 0.8051
# Epoch 100/100
# 15/15 [==============================] - 16s 1s/step - loss: 1.0022 - accuracy: 0.8862 - val_loss: 1.3640 - val_accuracy: 0.8136

# %%
# Evaluate the model on the validation set
y_val_pred = model.predict([scalar_X_val_pca, X_sequence_val_padded_transposed])
y_val_pred_classes = np.argmax(y_val_pred, axis=1)  # Convert predictions to class labels

y_val_true_classes = np.argmax(y_val, axis=1)  # Convert one-hot encoded labels to class labels

# Calculate metrics
accuracy = accuracy_score(y_val_true_classes, y_val_pred_classes)
precision = precision_score(y_val_true_classes, y_val_pred_classes, average='weighted')
recall = recall_score(y_val_true_classes, y_val_pred_classes, average='weighted')
f1 = f1_score(y_val_true_classes, y_val_pred_classes, average='weighted')

print("Validation Set Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")


from keras.utils import plot_model
# !pip install networkx
from IPython.display import Image, display

# Generate the model flowchart
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# Display the image in the notebook
display(Image(filename='model.png'))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# Dual-Axis plot to visualise training-validation loss and accuracy.
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color=color)
trainloss_line, = ax1.plot(history.history['loss'], color=color, label='Train Loss')
valloss_line, = ax1.plot(history.history['val_loss'], color=color, linestyle='dashed', label='Val Loss')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Accuracy', color=color)
trainacc_line, = ax2.plot(history.history['accuracy'], color=color, label='Train Acc')
valacc_line, = ax2.plot(history.history['val_accuracy'], color=color, linestyle='dashed', label='Val Acc')
ax2.tick_params(axis='y', labelcolor=color)

lns = [trainloss_line, valloss_line, trainacc_line, valacc_line]
ax1.legend(handles=lns, loc='center right')

fig.tight_layout()
plt.show()


# Make predictions using the trained model
y_pred = model.predict([scalar_X_val_pca, X_sequence_val_padded_transposed])

# Convert the one-hot encoded predictions back to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_val, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)

# Plot the confusion matrix
classes = ['activity' + str(x+1) for x in range(0, 21)]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='viridis', values_format='d')

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(rotation=90)
plt.show()

print("y_val", y_val.shape)
# Out:
# 8/8 [==============================] - 3s 400ms/step
# Validation Set Metrics:
# Accuracy: 0.8136
# Precision: 0.8301
# Recall: 0.8136
# F1-Score: 0.8123
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# 8/8 [==============================] - 3s 402ms/step
# y_val (236, 21)

# %% [markdown]
# SVM Model:

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time

# Convert y_train and y_val, which are one-hot encoded, to integer labels
y_train_int = np.argmax(y_train, axis=1)
y_val_int = np.argmax(y_val, axis=1)

# Flatten the sequence data
X_sequence_train_flattened = X_sequence_train_padded.reshape(X_sequence_train_padded.shape[0], -1)
X_sequence_val_flattened = X_sequence_val_padded.reshape(X_sequence_val_padded.shape[0], -1)

# Standardize the data
scaler = StandardScaler()
X_train_standardized = scaler.fit_transform(scalar_X_train_pca)
X_val_standardized = scaler.transform(scalar_X_val_pca)

## Create and train SVM model
print("Training started...")

# Get the start time
st = time.time()

svm_model = SVC(kernel='linear', C=1, probability=True)
svm_model.fit(X_train_standardized, y_train_int)
print("Training completed!")

# Get the end time
et = time.time()

# Calculate the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')

# Make predictions on validation and training data
y_val_pred = svm_model.predict(X_val_standardized)
y_train_pred = svm_model.predict(X_train_standardized)

# Calculate metrics for validation data
val_accuracy = accuracy_score(y_val_int, y_val_pred)
val_precision = precision_score(y_val_int, y_val_pred, average='macro')
val_recall = recall_score(y_val_int, y_val_pred, average='macro')
val_f1 = f1_score(y_val_int, y_val_pred, average='macro')

# Calculate metrics for training data
train_accuracy = accuracy_score(y_train_int, y_train_pred)
train_precision = precision_score(y_train_int, y_train_pred, average='macro')
train_recall = recall_score(y_train_int, y_train_pred, average='macro')
train_f1 = f1_score(y_train_int, y_train_pred, average='macro')

# Print all metrics
print(f'Training accuracy: {train_accuracy}')
print(f'Training precision: {train_precision}')
print(f'Training recall: {train_recall}')
print(f'Training F1: {train_f1}')
print('-'*50)
print(f'Validation accuracy: {val_accuracy}')
print(f'Validation precision: {val_precision}')
print(f'Validation recall: {val_recall}')
print(f'Validation F1: {val_f1}')

# Compute the confusion matrix
cm = confusion_matrix(y_val_int, y_val_pred)

# Plot the confusion matrix
classes = ['activity' + str(x+1) for x in range(0, 21)]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='viridis', values_format='d')

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(rotation=90)
plt.show()
# Out:
# Training started...
# Training completed!
# Execution time: 0.8149075508117676 seconds
# Training accuracy: 1.0
# Training precision: 1.0
# Training recall: 1.0
# Training F1: 1.0
# --------------------------------------------------
# Validation accuracy: 0.7542372881355932
# Validation precision: 0.7696365142793714
# Validation recall: 0.7564935064935064
# Validation F1: 0.7556102325950861
